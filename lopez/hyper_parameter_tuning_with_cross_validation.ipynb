# %%
import sys
import math

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import scipy.stats as stats

from multiprocessing import cpu_count
from tqdm import tqdm, tqdm_notebook

from mpengine import mpPandasObj
from util import cprintf
 
from hyper_parameter_tuning_with_cross_validation import clfHyperFit, clfHyperFit0, logUniform
# Out:
# KstestResult(statistic=0.014030230288036294, pvalue=0.03901506279875494)
# count    10000.000000
# mean        75.352231
# std        178.769572
# min          0.001001
# 25%          0.033526
# 50%          1.078852
# 75%         37.530520
# max        996.547395
# dtype: float64
